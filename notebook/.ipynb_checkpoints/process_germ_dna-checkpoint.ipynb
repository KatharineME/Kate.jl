# %%
include("../src/Kraft.jl")
# Out:
# Main.Kraft

# %%
Kraft.check_programs()
# Out:
# Checking programs ...
# `which skewer`
# /home/kwat/miniconda3/bin/skewer
# `which fastqc`
# /home/kwat/miniconda3/bin/fastqc
# `which bgzip`
# /home/kwat/miniconda3/bin/bgzip
# `which tabix`
# /home/kwat/miniconda3/bin/tabix
# `which minimap2`
# /home/kwat/miniconda3/bin/minimap2
# `which samtools`
# /home/kwat/miniconda3/bin/samtools
# `which bcftools`
# /home/kwat/miniconda3/bin/bcftools
# `which snpEff`
# /home/kwat/miniconda3/bin/snpEff
# `which kallisto`
# /home/kwat/miniconda3/bin/kallisto
# `bash -c 'source activate py2.7 && which configManta.py'`
# /home/kwat/miniconda3/envs/py2.7/bin/configManta.py
# `bash -c 'source activate py2.7 && which configureStrelkaGermlineWorkflow.py'`
# /home/kwat/miniconda3/envs/py2.7/bin/configureStrelkaGermlineWorkflow.py
# `bash -c 'source activate py2.7 && which configureStrelkaSomaticWorkflow.py'`
# /home/kwat/miniconda3/envs/py2.7/bin/configureStrelkaSomaticWorkflow.py

# %%
const path_dict = Kraft.make_path_dict("/home/kwat/garden/data")
# Out:
# Making path dict ...
# /home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.gz
# /home/kwat/garden/data/grch/chromosome.bed.gz
# /home/kwat/garden/data/grch/chrn_n.tsv
# /home/kwat/garden/data/grch/Homo_sapiens.GRCh38.cdna.all.fa.gz
# /home/kwat/garden/data/grch/enst_gene_name.tsv
# /home/kwat/garden/data/virus/sequences.fasta
# /home/kwat/garden/data/virus/sequences.fasta
# Dict{String,String} with 6 entries:
#   "dna.fa.gz"         => "/home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_n…
#   "chrn_n.tsv"        => "/home/kwat/garden/data/grch/chrn_n.tsv"
#   "chromosome.bed.gz" => "/home/kwat/garden/data/grch/chromosome.bed.gz"
#   "virus_cdna.fa.gz"  => "/home/kwat/garden/data/virus/sequences.fasta"
#   "cdna.fa.gz"        => "/home/kwat/garden/data/grch/Homo_sapiens.GRCh38.cdna.…
#   "dna.fa.bgz"        => "/home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_n…

# %%
const germ_dna_1_fq_gz = "/home/kwat/garden/sample/germ_dna.1.fastq.gz"

const germ_dna_2_fq_gz = "/home/kwat/garden/sample/germ_dna.2.fastq.gz"

const is_targeted = true

const output_dir = "/home/kwat/garden/sample/process_germ_dna"

const n_job = 2

const gb_memory = 16

const job_gb_memory = 1;
# Out:
# 1

# %%
for file_path::String in(
    germ_dna_1_fq_gz,
    germ_dna_2_fq_gz,
)
    
    if !isfile(file_path)
        
        error("$file_path doesn't exist.")
    
    end
    
end

# %%
const germ_trim_sequence_prefix = joinpath(
    output_dir,
    "trim_sequence",
    "germ",
)

Kraft.trim_sequence(
    germ_dna_1_fq_gz,
    germ_dna_2_fq_gz,
    germ_trim_sequence_prefix,
    n_job,
)

const germ_trim_1_fq_gz = "$germ_trim_sequence_prefix-trimmed-pair1.fastq.gz"

const germ_trim_2_fq_gz = replace(
    germ_trim_1_fq_gz,
    "pair1"=>"pair2",
);
# Out:
# (2019-06-24T21:21:35.013) Trimming sequence ...
# `skewer --threads 2 -x AGATCGGAAGAGC --compress --output /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ --quiet /home/kwat/garden/sample/germ_dna.1.fastq.gz /home/kwat/garden/sample/germ_dna.2.fastq.gz`
# .--. .-.
# : .--': :.-.
# `. `. : `'.' .--. .-..-..-. .--. .--.
# _`, :: . `.' '_.': `; `; :' '_.': ..'
# `.__.':_;:_;`.__.'`.__.__.'`.__.':_;
# skewer v0.2.2 [April 4, 2016]
# Parameters used:
# -- 3' end adapter sequence (-x):	AGATCGGAAGAGC
# -- maximum error ratio allowed (-r):	0.100
# -- maximum indel error ratio allowed (-d):	0.030
# -- minimum read length allowed after trimming (-l):	18
# -- file format (-f):		Sanger/Illumina 1.8+ FASTQ (auto detected)
# -- number of concurrent threads (-t):	2
# Mon Jun 24 21:21:35 2019 >> started
#
# Mon Jun 24 21:21:56 2019 >> done (21.252s)
# 1000000 read pairs processed; of these:
#       9 ( 0.00%) short read pairs filtered out after trimming by size control
#       1 ( 0.00%) empty read pairs filtered out after trimming by size control
#  999990 (100.00%) read pairs available; of these:
#     506 ( 0.05%) trimmed read pairs available after processing
#  999484 (99.95%) untrimmed read pairs available after processing
# log has been saved to "/home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed.log".
# (2019-06-24T21:21:56.291) Done in 21 seconds, 278 milliseconds.
# "/home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair2.fastq.gz"

# %%
Kraft.check_sequence(
    (
        germ_trim_1_fq_gz,
        germ_trim_2_fq_gz,
    ),
    joinpath(
        output_dir,
        "check_sequence",
    ),
    n_job,
)
# Out:
# (2019-06-24T21:21:56.626) Checking sequence ...
# `fastqc --threads 2 --outdir /home/kwat/garden/sample/process_germ_dna/check_sequence /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair1.fastq.gz /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair2.fastq.gz`
# Started analysis of germ-trimmed-pair1.fastq.gz
# Started analysis of germ-trimmed-pair2.fastq.gz
# Approx 5% complete for germ-trimmed-pair1.fastq.gz
# Approx 5% complete for germ-trimmed-pair2.fastq.gz
# Approx 10% complete for germ-trimmed-pair1.fastq.gz
# Approx 10% complete for germ-trimmed-pair2.fastq.gz
# Approx 15% complete for germ-trimmed-pair1.fastq.gz
# Approx 15% complete for germ-trimmed-pair2.fastq.gz
# Approx 20% complete for germ-trimmed-pair1.fastq.gz
# Approx 20% complete for germ-trimmed-pair2.fastq.gz
# Approx 25% complete for germ-trimmed-pair1.fastq.gz
# Approx 25% complete for germ-trimmed-pair2.fastq.gz
# Approx 30% complete for germ-trimmed-pair1.fastq.gz
# Approx 30% complete for germ-trimmed-pair2.fastq.gz
# Approx 35% complete for germ-trimmed-pair1.fastq.gz
# Approx 35% complete for germ-trimmed-pair2.fastq.gz
# Approx 40% complete for germ-trimmed-pair1.fastq.gz
# Approx 40% complete for germ-trimmed-pair2.fastq.gz
# Approx 45% complete for germ-trimmed-pair1.fastq.gz
# Approx 45% complete for germ-trimmed-pair2.fastq.gz
# Approx 50% complete for germ-trimmed-pair1.fastq.gz
# Approx 50% complete for germ-trimmed-pair2.fastq.gz
# Approx 55% complete for germ-trimmed-pair1.fastq.gz
# Approx 55% complete for germ-trimmed-pair2.fastq.gz
# Approx 60% complete for germ-trimmed-pair1.fastq.gz
# Approx 60% complete for germ-trimmed-pair2.fastq.gz
# Approx 65% complete for germ-trimmed-pair1.fastq.gz
# Approx 65% complete for germ-trimmed-pair2.fastq.gz
# Approx 70% complete for germ-trimmed-pair1.fastq.gz
# Approx 70% complete for germ-trimmed-pair2.fastq.gz
# Approx 75% complete for germ-trimmed-pair1.fastq.gz
# Approx 75% complete for germ-trimmed-pair2.fastq.gz
# Approx 80% complete for germ-trimmed-pair1.fastq.gz
# Approx 80% complete for germ-trimmed-pair2.fastq.gz
# Approx 85% complete for germ-trimmed-pair1.fastq.gz
# Approx 85% complete for germ-trimmed-pair2.fastq.gz
# Approx 90% complete for germ-trimmed-pair1.fastq.gz
# Approx 90% complete for germ-trimmed-pair2.fastq.gz
# Approx 95% complete for germ-trimmed-pair1.fastq.gz
# Approx 95% complete for germ-trimmed-pair2.fastq.gz
# Analysis complete for germ-trimmed-pair1.fastq.gz
# Analysis complete for germ-trimmed-pair2.fastq.gz
# (2019-06-24T21:22:09.975) Done in 13 seconds, 349 milliseconds.

# %%
const germ_bam = joinpath(
    output_dir,
    "align_sequence",
    "germ_dna.bam",
)

Kraft.align_sequence(
    germ_trim_1_fq_gz,
    germ_trim_2_fq_gz,
    "Germ",
    path_dict["dna.fa.gz"],
    germ_bam,
    n_job,
    job_gb_memory,
)
# Out:
# (2019-06-24T21:22:10.107) Aligning sequence ...
# pipeline(pipeline(pipeline(pipeline(`minimap2 -x sr -t 2 -K 1G -R '@RG\tID:Germ\tSM:Germ' -a /home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.gz.mmi /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair1.fastq.gz /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair2.fastq.gz`, stdout=`samtools sort --threads 2 -m 1G -n`), stdout=`samtools fixmate --threads 2 -m - -`), stdout=`samtools sort --threads 2 -m 1G`), stdout=Base.FileRedirect("/home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam.tmp", false))
# [WARNING] Indexing parameters (-k, -w or -H) overridden by parameters used in the prebuilt index.
# [M::main::7.942*0.90] loaded/built the index for 195 target sequence(s)
# [M::mm_mapopt_update::7.942*0.90] mid_occ = 1000
# [M::mm_idx_stat] kmer size: 15; skip: 10; is_hpc: 0; #seq: 195
# [M::mm_idx_stat::8.802*0.91] distinct minimizers: 100167746 (38.80% are singletons); average occurrences: 5.519; average spacing: 5.607
# [M::worker_pipeline::97.186*1.83] mapped 1999980 sequences
# [M::main] Version: 2.17-r941
# [M::main] CMD: minimap2 -x sr -t 2 -K 1G -R @RG\tID:Germ\tSM:Germ -a /home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.gz.mmi /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair1.fastq.gz /home/kwat/garden/sample/process_germ_dna/trim_sequence/germ-trimmed-pair2.fastq.gz
# [M::main] Real time: 97.443 sec; CPU: 178.011 sec; Peak RSS: 8.534 GB
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# [bam_sort_core] merging from 0 files and 2 in-memory blocks...
# `samtools markdup --threads 2 -s /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam.tmp /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam`
# `samtools index -@ 2 /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam`
# READ 2002462 WRITTEN 2002462
# EXCLUDED 8602 EXAMINED 1993860
# PAIRED 1988572 SINGLE 5288
# DULPICATE PAIR 57366 DUPLICATE SINGLE 1279
# DUPLICATE TOTAL 58645
# pipeline(`samtools flagstat --threads 2 /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam`, stdout=Base.FileRedirect("/home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam.flagstat", false))
# (2019-06-24T21:24:07.375) Done in 1 minute, 57 seconds, 268 milliseconds.

# %%
const find_mutation_dir = joinpath(
    output_dir,
    "find_variant",
)

Kraft.find_variant(
    germ_bam,
    nothing,
    path_dict["dna.fa.bgz"],
    path_dict["chromosome.bed.gz"],
    is_targeted,
    path_dict["chrn_n.tsv"],
    find_mutation_dir,
    n_job,
    gb_memory,
)
# Out:
# (2019-06-24T21:24:07.524) Finding variant ...
# `bash -c 'source activate py2.7 && configManta.py --referenceFasta /home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.bgz --callRegions /home/kwat/garden/data/grch/chromosome.bed.gz --exome --bam /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam --outputContig --runDir /home/kwat/garden/sample/process_germ_dna/find_variant/manta && /home/kwat/garden/sample/process_germ_dna/find_variant/manta/runWorkflow.py --mode local --jobs 2 --memGb 16 --quiet'`
#
# Successfully created workflow run script.
# To execute the workflow, run the following script and set appropriate options:
#
# /home/kwat/garden/sample/process_germ_dna/find_variant/manta/runWorkflow.py
# `bash -c 'source activate py2.7 && configureStrelkaGermlineWorkflow.py --referenceFasta /home/kwat/garden/data/grch/GCA_000001405.15_GRCh38_no_alt_analysis_set.fna.bgz --callRegions /home/kwat/garden/data/grch/chromosome.bed.gz --exome --bam /home/kwat/garden/sample/process_germ_dna/align_sequence/germ_dna.bam --runDir /home/kwat/garden/sample/process_germ_dna/find_variant/strelka && /home/kwat/garden/sample/process_germ_dna/find_variant/strelka/runWorkflow.py --mode local --jobs 2 --memGb 16 --quiet'`
#
# Successfully created workflow run script.
# To execute the workflow, run the following script and set appropriate options:
#
# /home/kwat/garden/sample/process_germ_dna/find_variant/strelka/runWorkflow.py
# pipeline(pipeline(pipeline(`bcftools concat --threads 2 --allow-overlaps /home/kwat/garden/sample/process_germ_dna/find_variant/manta/results/variants/diploidSV.vcf.gz /home/kwat/garden/sample/process_germ_dna/find_variant/strelka/results/variants/variants.vcf.gz`, stdout=`bcftools annotate --threads 2 --rename-chrs /home/kwat/garden/data/grch/chrn_n.tsv`), stdout=`bgzip --threads 2 --stdout`), stdout=Base.FileRedirect("/home/kwat/garden/sample/process_germ_dna/find_variant/concat.vcf.gz", false))
# `tabix /home/kwat/garden/sample/process_germ_dna/find_variant/concat.vcf.gz`
# pipeline(pipeline(`snpEff -Xmx16g GRCh38.86 -noLog -verbose -csvStats /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/stats.csv -htmlStats /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/stats.html /home/kwat/garden/sample/process_germ_dna/find_variant/concat.vcf.gz`, stdout=`bgzip --threads 2 --stdout`), stdout=Base.FileRedirect("/home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/snpeff.vcf.gz", false))
# 00:00:00	SnpEff version SnpEff 4.3t (build 2017-11-24 10:18), by Pablo Cingolani
# 00:00:00	Command: 'ann'
# 00:00:00	Reading configuration file 'snpEff.config'. Genome: 'GRCh38.86'
# 00:00:00	Reading config file: /home/kwat/github/Kraft.jl/notebook/snpEff.config
# 00:00:00	Reading config file: /home/kwat/miniconda3/share/snpeff-4.3.1t-2/snpEff.config
# 00:00:00	done
# 00:00:00	Reading database for genome version 'GRCh38.86' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/snpEffectPredictor.bin' (this might take a while)
# 00:00:13	done
# 00:00:13	Reading NextProt database from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/nextProt.bin'
# 00:00:14	NextProt database: 652574 markers loaded.
# 00:00:14	Adding transcript info to NextProt markers.
# 00:00:14	NextProt database: 652574 markers added.
# 00:00:14	Loading PWMs from : /home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/pwms.bin
# 00:00:14	Loading Motifs from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/motif.bin'
# 00:00:14		Motif database: 511011 markers loaded.
# 00:00:15	Loading interactions from : /home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/interactions.bin
# 00:00:21		Interactions: 1793688 added, 0 skipped.
# 00:00:21	Building interval forest
# 00:00:26	done.
# 00:00:26	Genome stats :
# #-----------------------------------------------
# # Genome name                : 'Homo_sapiens'
# # Genome version             : 'GRCh38.86'
# # Genome ID                  : 'GRCh38.86[0]'
# # Has protein coding info    : true
# # Has Tr. Support Level info : true
# # Genes                      : 58051
# # Protein coding genes       : 20423
# #-----------------------------------------------
# # Transcripts                : 198002
# # Avg. transcripts per gene  : 3.41
# # TSL transcripts            : 166906
# #-----------------------------------------------
# # Checked transcripts        :
# #               AA sequences :      0 ( 0.00% )
# #              DNA sequences : 163038 ( 82.34% )
# #-----------------------------------------------
# # Protein coding transcripts : 94384
# #              Length errors :  13357 ( 14.15% )
# #  STOP codons in CDS errors :     51 ( 0.05% )
# #         START codon errors :  11250 ( 11.92% )
# #        STOP codon warnings :   7169 ( 7.60% )
# #              UTR sequences :  91549 ( 46.24% )
# #               Total Errors :  23099 ( 24.47% )
# #-----------------------------------------------
# # Cds                        : 704604
# # Exons                      : 1182163
# # Exons with sequence        : 1182163
# # Exons without sequence     : 0
# # Avg. exons per transcript  : 5.97
# # WARNING!                   : Mitochondrion chromosome 'MT' does not have a mitochondrion codon table (codon table = 'Standard'). You should update the config file.
# #-----------------------------------------------
# # Number of chromosomes      : 524
# # Chromosomes                : Format 'chromo_name size codon_table'
# #		'HSCHR1_2_CTG3'	248975002	Standard
# #		'HSCHR1_1_CTG31'	248973653	Standard
# #		'HSCHR1_2_CTG31'	248971826	Standard
# #		'HSCHR1_1_CTG3'	248968406	Standard
# #		'HSCHR1_3_CTG31'	248967909	Standard
# #		'HSCHR1_4_CTG3'	248963886	Standard
# #		'HSCHR1_2_CTG32_1'	248962488	Standard
# #		'HSCHR1_3_CTG3'	248961700	Standard
# #		'HSCHR1_1_CTG11'	248961539	Standard
# #		'HSCHR1_3_CTG32_1'	248960761	Standard
# #		'HSCHR1_5_CTG32_1'	248960213	Standard
# #		'HSCHR1_1_CTG32_1'	248960143	Standard
# #		'HG1832_PATCH'	248959779	Standard
# #		'HG2095_PATCH'	248959131	Standard
# #		'HSCHR1_ALT2_1_CTG32_1'	248958866	Standard
# #		'HSCHR1_4_CTG32_1'	248958766	Standard
# #		'HG2104_PATCH'	248958259	Standard
# #		'HG986_PATCH'	248956639	Standard
# #		'1'	248956422	Standard
# #		'HG2058_PATCH'	248956422	Standard
# #		'HSCHR1_4_CTG31'	248955631	Standard
# #		'HG1342_HG2282_PATCH'	248929249	Standard
# #		'HSCHR1_5_CTG3'	248926662	Standard
# #		'HG2290_PATCH'	242235269	Standard
# #		'HSCHR2_2_CTG7'	242223512	Standard
# #		'HSCHR2_1_CTG7_2'	242210518	Standard
# #		'HSCHR2_5_CTG7_2'	242199685	Standard
# #		'HSCHR2_2_CTG7_2'	242199609	Standard
# #		'HSCHR2_1_CTG5'	242199562	Standard
# #		'HSCHR2_1_CTG15'	242198904	Standard
# #		'HSCHR2_2_CTG15'	242198544	Standard
# #		'HSCHR2_2_CTG1'	242198346	Standard
# #		'HSCHR2_6_CTG7_2'	242198149	Standard
# #		'HSCHR2_4_CTG7_2'	242196589	Standard
# #		'HSCHR2_3_CTG1'	242195626	Standard
# #		'HSCHR2_1_CTG1'	242194896	Standard
# #		'HSCHR2_3_CTG7_2'	242194557	Standard
# #		'HSCHR2_3_CTG15'	242194292	Standard
# #		'HSCHR2_1_CTG7'	242193540	Standard
# #		'HG2233_PATCH'	242193535	Standard
# #		'2'	242193529	Standard
# #		'HG2232_PATCH'	242193529	Standard
# #		'HSCHR2_4_CTG1'	242191076	Standard
# #		'HSCHR3_1_CTG2_1'	198306097	Standard
# #		'HSCHR3_1_CTG3'	198302882	Standard
# #		'HSCHR3_4_CTG2_1'	198301383	Standard
# #		'HSCHR3_5_CTG2_1'	198300594	Standard
# #		'HSCHR3_3_CTG2_1'	198300421	Standard
# #		'HSCHR3_3_CTG1'	198300110	Standard
# #		'HSCHR3_2_CTG2_1'	198298736	Standard
# #		'HSCHR3_1_CTG1'	198297480	Standard
# #		'HSCHR3_2_CTG3'	198296961	Standard
# #		'HSCHR3_4_CTG3'	198296867	Standard
# #		'HG2022_PATCH'	198295941	Standard
# #		'HSCHR3_8_CTG3'	198295934	Standard
# #		'HG126_PATCH'	198295908	Standard
# #		'HG2235_PATCH'	198295655	Standard
# #		'3'	198295559	Standard
# #		'HG2066_PATCH'	198295555	Standard
# #		'HSCHR3_6_CTG3'	198294921	Standard
# #		'HSCHR3_7_CTG3'	198294497	Standard
# #		'HSCHR3_5_CTG3'	198293785	Standard
# #		'HSCHR3_3_CTG3'	198293223	Standard
# #		'HSCHR3_9_CTG3'	198291952	Standard
# #		'HG2237_PATCH'	198290329	Standard
# #		'HSCHR4_11_CTG12'	190233769	Standard
# #		'HSCHR4_1_CTG12'	190227204	Standard
# #		'HSCHR4_7_CTG12'	190225141	Standard
# #		'HSCHR4_1_CTG6'	190224838	Standard
# #		'HSCHR4_1_CTG4'	190221757	Standard
# #		'HSCHR4_4_CTG12'	190220704	Standard
# #		'HSCHR4_5_CTG12'	190219562	Standard
# #		'HSCHR4_9_CTG12'	190219005	Standard
# #		'HSCHR4_1_CTG8_1'	190218838	Standard
# #		'HSCHR4_6_CTG12'	190218533	Standard
# #		'HSCHR4_8_CTG12'	190218480	Standard
# #		'HSCHR4_3_CTG12'	190218028	Standard
# #		'HSCHR4_2_CTG4'	190217898	Standard
# #		'4'	190214555	Standard
# #		'HSCHR4_2_CTG12'	190206797	Standard
# #		'HG2023_PATCH'	190147504	Standard
# #		'HSCHR4_1_CTG9'	190096932	Standard
# #		'HSCHR5_1_CTG1'	181558402	Standard
# #		'HSCHR5_3_CTG1_1'	181554865	Standard
# #		'HSCHR5_2_CTG1'	181547139	Standard
# #		'HSCHR5_4_CTG1_1'	181546281	Standard
# #		'HSCHR5_7_CTG1'	181544732	Standard
# #		'HSCHR5_1_CTG5'	181543736	Standard
# #		'HSCHR5_3_CTG1'	181542495	Standard
# #		'HSCHR5_2_CTG5'	181542206	Standard
# #		'HSCHR5_6_CTG1'	181540245	Standard
# #		'HSCHR5_5_CTG1'	181539933	Standard
# #		'HSCHR5_3_CTG5'	181538569	Standard
# #		'5'	181538259	Standard
# #		'HSCHR5_4_CTG1'	181537434	Standard
# #		'HSCHR5_1_CTG1_1'	180863570	Standard
# #		'HSCHR5_2_CTG1_1'	180753562	Standard
# #		'HSCHR6_MHC_MCF_CTG1'	170976334	Standard
# #		'HSCHR6_MHC_MANN_CTG1'	170959829	Standard
# #		'HSCHR6_MHC_SSTO_CTG1'	170946136	Standard
# #		'HSCHR6_MHC_APD_CTG1'	170845044	Standard
# #		'HSCHR6_1_CTG3'	170836231	Standard
# #		'HSCHR6_1_CTG2'	170833811	Standard
# #		'HSCHR6_1_CTG6'	170818797	Standard
# #		'HG2072_PATCH'	170816182	Standard
# #		'HSCHR6_1_CTG9'	170815583	Standard
# #		'HSCHR6_1_CTG5'	170815302	Standard
# #		'HSCHR6_8_CTG1'	170813052	Standard
# #		'HSCHR6_1_CTG7'	170812567	Standard
# #		'HG2128_PATCH'	170811684	Standard
# #		'HSCHR6_1_CTG10'	170810830	Standard
# #		'HSCHR6_1_CTG8'	170810115	Standard
# #		'HSCHR6_1_CTG4'	170808607	Standard
# #		'6'	170805979	Standard
# #		'HSCHR6_MHC_DBB_CTG1'	170783898	Standard
# #		'HG1651_PATCH'	170779650	Standard
# #		'HSCHR6_MHC_QBL_CTG1'	170734801	Standard
# #		'HSCHR6_MHC_COX_CTG1'	170727598	Standard
# #		'HSCHR7_2_CTG6'	159407160	Standard
# #		'HSCHR7_1_CTG6'	159351981	Standard
# #		'HSCHR7_2_CTG7'	159349352	Standard
# #		'HSCHR7_1_CTG1'	159349278	Standard
# #		'HSCHR7_1_CTG4_4'	159348604	Standard
# #		'HSCHR7_2_CTG1'	159348294	Standard
# #		'HSCHR7_1_CTG7'	159346281	Standard
# #		'7'	159345973	Standard
# #		'HG2239_PATCH'	159345319	Standard
# #		'HSCHR7_3_CTG6'	159344441	Standard
# #		'HSCHR7_2_CTG4_4'	159333789	Standard
# #		'HSCHRX_2_CTG12'	156053172	Standard
# #		'HSCHRX_1_CTG3'	156043585	Standard
# #		'X'	156040895	Standard
# #		'HSCHRX_2_CTG3'	156039875	Standard
# #		'HSCHR8_1_CTG6'	145150400	Standard
# #		'HSCHR8_5_CTG7'	145144538	Standard
# #		'HSCHR8_4_CTG7'	145143933	Standard
# #		'HSCHR8_1_CTG7'	145142033	Standard
# #		'HSCHR8_2_CTG7'	145141868	Standard
# #		'HSCHR8_6_CTG7'	145141837	Standard
# #		'HSCHR8_2_CTG1'	145141567	Standard
# #		'HSCHR8_4_CTG1'	145141010	Standard
# #		'8'	145138636	Standard
# #		'HSCHR8_7_CTG1'	145138198	Standard
# #		'HSCHR8_5_CTG1'	145137619	Standard
# #		'HSCHR8_6_CTG1'	145136257	Standard
# #		'HSCHR8_3_CTG1'	145130612	Standard
# #		'HSCHR8_3_CTG7'	145125643	Standard
# #		'HSCHR8_1_CTG1'	145124952	Standard
# #		'HSCHR8_8_CTG1'	145123326	Standard
# #		'HSCHR8_9_CTG1'	144983589	Standard
# #		'HSCHR9_1_CTG1'	138409529	Standard
# #		'HSCHR9_1_CTG4'	138405815	Standard
# #		'HSCHR9_1_CTG5'	138404305	Standard
# #		'HSCHR9_1_CTG2'	138402913	Standard
# #		'HSCHR9_1_CTG3'	138400797	Standard
# #		'HSCHR9_1_CTG6'	138399532	Standard
# #		'HSCHR9_1_CTG7'	138399111	Standard
# #		'HG2030_PATCH'	138394865	Standard
# #		'9'	138394717	Standard
# #		'HG151_NOVEL_TEST'	135097696	Standard
# #		'HSCHR11_1_CTG5'	135097255	Standard
# #		'HSCHR11_1_CTG1_2'	135096748	Standard
# #		'HG142_HG150_NOVEL_TEST'	135094228	Standard
# #		'HSCHR11_2_CTG1'	135093444	Standard
# #		'HSCHR11_1_CTG1_1'	135092355	Standard
# #		'HSCHR11_1_CTG6'	135092332	Standard
# #		'HSCHR11_3_CTG1'	135092180	Standard
# #		'HG2116_PATCH'	135090698	Standard
# #		'HSCHR11_1_CTG3'	135090275	Standard
# #		'HG107_PATCH'	135088590	Standard
# #		'HSCHR11_1_CTG8'	135088433	Standard
# #		'11'	135086622	Standard
# #		'HG2217_PATCH'	135086621	Standard
# #		'HSCHR11_1_CTG7'	135085484	Standard
# #		'HSCHR11_2_CTG1_1'	135083841	Standard
# #		'HSCHR11_1_CTG2'	135083598	Standard
# #		'HSCHR10_1_CTG1'	133844722	Standard
# #		'HSCHR10_1_CTG4'	133815819	Standard
# #		'HSCHR10_1_CTG2'	133813485	Standard
# #		'HSCHR10_1_CTG6'	133801239	Standard
# #		'HG2191_PATCH'	133799479	Standard
# #		'HG2244_HG2245_PATCH'	133797425	Standard
# #		'10'	133797422	Standard
# #		'HG2334_PATCH'	133797389	Standard
# #		'HG2242_HG2243_PATCH'	133797297	Standard
# #		'HG2241_PATCH'	133792722	Standard
# #		'HSCHR10_1_CTG3'	133783218	Standard
# #		'HSCHR12_2_CTG2'	133307257	Standard
# #		'HSCHR12_7_CTG2_1'	133289478	Standard
# #		'HSCHR12_1_CTG2_1'	133284468	Standard
# #		'HSCHR12_2_CTG2_1'	133282358	Standard
# #		'HSCHR12_2_CTG1'	133282237	Standard
# #		'HSCHR12_3_CTG2_1'	133281486	Standard
# #		'HSCHR12_1_CTG2'	133281368	Standard
# #		'HSCHR12_4_CTG2_1'	133281351	Standard
# #		'HSCHR12_5_CTG2_1'	133279478	Standard
# #		'HSCHR12_1_CTG1'	133279324	Standard
# #		'HSCHR12_4_CTG2'	133277582	Standard
# #		'HSCHR12_6_CTG2_1'	133275361	Standard
# #		'HG1362_PATCH'	133275314	Standard
# #		'12'	133275309	Standard
# #		'HSCHR12_5_CTG2'	133275237	Standard
# #		'HG23_PATCH'	133275184	Standard
# #		'HG2063_PATCH'	133275140	Standard
# #		'HG2247_PATCH'	133274000	Standard
# #		'HSCHR12_3_CTG2'	133271566	Standard
# #		'HG2291_PATCH'	114534236	Standard
# #		'HG2216_PATCH'	114376428	Standard
# #		'HSCHR13_1_CTG7'	114374491	Standard
# #		'HSCHR13_1_CTG3'	114370226	Standard
# #		'HSCHR13_1_CTG8'	114368996	Standard
# #		'HSCHR13_1_CTG4'	114368332	Standard
# #		'HSCHR13_1_CTG2'	114368315	Standard
# #		'HSCHR13_1_CTG6'	114367169	Standard
# #		'HSCHR13_1_CTG5'	114365350	Standard
# #		'13'	114364328	Standard
# #		'HG2249_PATCH'	114364211	Standard
# #		'HG2288_HG2289_PATCH'	114360394	Standard
# #		'HSCHR13_1_CTG1'	114348172	Standard
# #		'HSCHR14_3_CTG1'	107067894	Standard
# #		'HSCHR14_2_CTG1'	107050862	Standard
# #		'HSCHR14_1_CTG1'	107047377	Standard
# #		'HSCHR14_7_CTG1'	107045728	Standard
# #		'14'	107043718	Standard
# #		'HSCHR15_4_CTG8'	102071387	Standard
# #		'HSCHR15_5_CTG8'	102070278	Standard
# #		'HSCHR15_2_CTG8'	102003326	Standard
# #		'HSCHR15_1_CTG8'	102002809	Standard
# #		'HSCHR15_3_CTG8'	101999716	Standard
# #		'HSCHR15_1_CTG1'	101998275	Standard
# #		'HSCHR15_2_CTG3'	101995966	Standard
# #		'HSCHR15_1_CTG3'	101994657	Standard
# #		'HSCHR15_3_CTG3'	101993763	Standard
# #		'15'	101991189	Standard
# #		'HSCHR15_6_CTG8'	101521929	Standard
# #		'HSCHR16_1_CTG1'	90426449	Standard
# #		'HSCHR16_3_CTG3_1'	90346170	Standard
# #		'HSCHR16_5_CTG1'	90344275	Standard
# #		'HSCHR16_2_CTG3_1'	90343477	Standard
# #		'HSCHR16_4_CTG3_1'	90343133	Standard
# #		'HSCHR16_CTG2'	90341867	Standard
# #		'HSCHR16_4_CTG1'	90340369	Standard
# #		'HSCHR16_3_CTG1'	90340304	Standard
# #		'16'	90338345	Standard
# #		'HSCHR16_1_CTG3_1'	90335239	Standard
# #		'HSCHR17_1_CTG5'	83552665	Standard
# #		'HSCHR17_10_CTG4'	83359087	Standard
# #		'HSCHR17_1_CTG1'	83290495	Standard
# #		'HSCHR17_3_CTG4'	83269063	Standard
# #		'HSCHR17_1_CTG4'	83264766	Standard
# #		'HSCHR17_9_CTG4'	83263791	Standard
# #		'HSCHR17_2_CTG4'	83263494	Standard
# #		'HSCHR17_2_CTG1'	83259496	Standard
# #		'HSCHR17_8_CTG4'	83258474	Standard
# #		'HSCHR17_3_CTG2'	83258211	Standard
# #		'HSCHR17_4_CTG4'	83257896	Standard
# #		'17'	83257441	Standard
# #		'HSCHR17_1_CTG2'	83256362	Standard
# #		'HSCHR17_1_CTG9'	83255504	Standard
# #		'HSCHR17_5_CTG4'	83247119	Standard
# #		'HSCHR17_6_CTG4'	83246071	Standard
# #		'HSCHR17_2_CTG2'	83160220	Standard
# #		'HSCHR17_2_CTG5'	83086355	Standard
# #		'HSCHR17_7_CTG4'	83058228	Standard
# #		'HSCHR18_2_CTG2'	80442734	Standard
# #		'HSCHR18_1_CTG2'	80386177	Standard
# #		'HSCHR18_1_CTG2_1'	80382671	Standard
# #		'HSCHR18_1_CTG1_1'	80380517	Standard
# #		'HSCHR18_2_CTG1_1'	80379367	Standard
# #		'HSCHR18_3_CTG2_1'	80379039	Standard
# #		'HSCHR18_5_CTG1_1'	80378965	Standard
# #		'HSCHR18_2_CTG2_1'	80378720	Standard
# #		'HSCHR18_4_CTG1_1'	80378406	Standard
# #		'HG2213_PATCH'	80377536	Standard
# #		'HSCHR18_ALT2_CTG2_1'	80376883	Standard
# #		'HSCHR18_ALT21_CTG2_1'	80376343	Standard
# #		'18'	80373285	Standard
# #		'HSCHR20_1_CTG1'	64450183	Standard
# #		'HSCHR20_1_CTG3'	64447812	Standard
# #		'HSCHR20_1_CTG4'	64446453	Standard
# #		'20'	64444167	Standard
# #		'HSCHR20_1_CTG2'	64441059	Standard
# #		'HSCHR19KIR_FH15_B_HAP_CTG3_1'	58689284	Standard
# #		'HSCHR19KIR_FH05_B_HAP_CTG3_1'	58689016	Standard
# #		'HSCHR19KIR_FH13_BA2_HAP_CTG3_1'	58662330	Standard
# #		'HSCHR19KIR_RSH_BA2_HAP_CTG3_1'	58662237	Standard
# #		'HSCHR19KIR_G248_BA2_HAP_CTG3_1'	58661364	Standard
# #		'HSCHR19LRC_LRC_J_CTG3_1'	58650772	Standard
# #		'HSCHR19KIR_FH08_BAX_HAP_CTG3_1'	58647709	Standard
# #		'HSCHR19KIR_GRC212_AB_HAP_CTG3_1'	58644315	Standard
# #		'HG2021_PATCH'	58632883	Standard
# #		'HSCHR19KIR_LUCE_BDEL_HAP_CTG3_1'	58631446	Standard
# #		'HSCHR19KIR_RP5_B_HAP_CTG3_1'	58631402	Standard
# #		'HSCHR19KIR_T7526_BDEL_HAP_CTG3_1'	58631206	Standard
# #		'HSCHR19_2_CTG2'	58627095	Standard
# #		'HSCHR19_3_CTG3_1'	58625958	Standard
# #		'HSCHR19_3_CTG2'	58625823	Standard
# #		'HSCHR19_4_CTG3_1'	58625731	Standard
# #		'HSCHR19LRC_LRC_S_CTG3_1'	58625321	Standard
# #		'HSCHR19_1_CTG3_1'	58624789	Standard
# #		'HSCHR19_1_CTG2'	58624032	Standard
# #		'HSCHR19LRC_LRC_I_CTG3_1'	58623235	Standard
# #		'HSCHR19_4_CTG2'	58619803	Standard
# #		'HSCHR19_5_CTG2'	58619095	Standard
# #		'HSCHR19_2_CTG3_1'	58618601	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_C_P_CTG3_1'	58618008	Standard
# #		'HSCHR19KIR_FH08_A_HAP_CTG3_1'	58617658	Standard
# #		'HG26_PATCH'	58617652	Standard
# #		'HSCHR19KIR_G248_A_HAP_CTG3_1'	58617652	Standard
# #		'HSCHR19KIR_ABC08_AB_HAP_T_P_CTG3_1'	58617636	Standard
# #		'HSCHR19KIR_LUCE_A_HAP_CTG3_1'	58617634	Standard
# #		'HSCHR19KIR_ABC08_A1_HAP_CTG3_1'	58617625	Standard
# #		'19'	58617616	Standard
# #		'HSCHR19KIR_RSH_A_HAP_CTG3_1'	58617616	Standard
# #		'HSCHR19KIR_G085_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_T7526_A_HAP_CTG3_1'	58617601	Standard
# #		'HSCHR19KIR_FH06_A_HAP_CTG3_1'	58617587	Standard
# #		'HSCHR19KIR_FH15_A_HAP_CTG3_1'	58617473	Standard
# #		'HSCHR19KIR_FH05_A_HAP_CTG3_1'	58616795	Standard
# #		'HSCHR19KIR_FH13_A_HAP_CTG3_1'	58616725	Standard
# #		'HSCHR19KIR_FH06_BA1_HAP_CTG3_1'	58603994	Standard
# #		'HSCHR19KIR_G085_BA1_HAP_CTG3_1'	58603800	Standard
# #		'HSCHR19KIR_GRC212_BA1_HAP_CTG3_1'	58602595	Standard
# #		'HSCHR19LRC_LRC_T_CTG3_1'	58561614	Standard
# #		'HSCHR19LRC_COX1_CTG3_1'	58546647	Standard
# #		'HSCHR19LRC_PGF1_CTG3_1'	58546031	Standard
# #		'HSCHR19LRC_PGF2_CTG3_1'	58355410	Standard
# #		'HSCHR19LRC_COX2_CTG3_1'	58288451	Standard
# #		'HG2062_PATCH'	57262172	Standard
# #		'Y'	57227415	Standard
# #		'HSCHR22_1_CTG7'	50872732	Standard
# #		'HSCHR22_7_CTG1'	50845852	Standard
# #		'HSCHR22_1_CTG6'	50842710	Standard
# #		'HSCHR22_5_CTG1'	50832153	Standard
# #		'HSCHR22_8_CTG1'	50832130	Standard
# #		'HSCHR22_2_CTG1'	50830603	Standard
# #		'HSCHR22_1_CTG3'	50827573	Standard
# #		'HSCHR22_1_CTG4'	50824699	Standard
# #		'HSCHR22_1_CTG5'	50821308	Standard
# #		'HG1311_PATCH'	50818486	Standard
# #		'22'	50818468	Standard
# #		'HSCHR22_3_CTG1'	50818468	Standard
# #		'HSCHR22_6_CTG1'	50815919	Standard
# #		'HSCHR22_1_CTG1'	50806372	Standard
# #		'HSCHR22_4_CTG1'	50806321	Standard
# #		'HSCHR22_1_CTG2'	50788525	Standard
# #		'HSCHR21_1_CTG1_1'	46722569	Standard
# #		'HSCHR21_4_CTG1_1'	46719541	Standard
# #		'HSCHR21_2_CTG1_1'	46716685	Standard
# #		'HSCHR21_3_CTG1_1'	46715777	Standard
# #		'HSCHR21_6_CTG1_1'	46713516	Standard
# #		'HSCHR21_8_CTG1_1'	46713185	Standard
# #		'HSCHR21_5_CTG2'	46712294	Standard
# #		'21'	46709983	Standard
# #		'KI270728.1'	1872759	Standard
# #		'KI270727.1'	448248	Standard
# #		'KI270442.1'	392061	Standard
# #		'KI270729.1'	280839	Standard
# #		'GL000225.1'	211173	Standard
# #		'KI270743.1'	210658	Standard
# #		'GL000008.2'	209709	Standard
# #		'GL000009.2'	201709	Standard
# #		'KI270747.1'	198735	Standard
# #		'KI270722.1'	194050	Standard
# #		'GL000194.1'	191469	Standard
# #		'KI270742.1'	186739	Standard
# #		'GL000205.2'	185591	Standard
# #		'GL000195.1'	182896	Standard
# #		'KI270736.1'	181920	Standard
# #		'KI270733.1'	179772	Standard
# #		'GL000224.1'	179693	Standard
# #		'GL000219.1'	179198	Standard
# #		'KI270719.1'	176845	Standard
# #		'GL000216.2'	176608	Standard
# #		'KI270712.1'	176043	Standard
# #		'KI270706.1'	175055	Standard
# #		'KI270725.1'	172810	Standard
# #		'KI270744.1'	168472	Standard
# #		'KI270734.1'	165050	Standard
# #		'GL000213.1'	164239	Standard
# #		'GL000220.1'	161802	Standard
# #		'KI270715.1'	161471	Standard
# #		'GL000218.1'	161147	Standard
# #		'KI270749.1'	158759	Standard
# #		'KI270741.1'	157432	Standard
# #		'GL000221.1'	155397	Standard
# #		'KI270716.1'	153799	Standard
# #		'KI270731.1'	150754	Standard
# #		'KI270751.1'	150742	Standard
# #		'KI270750.1'	148850	Standard
# #		'KI270519.1'	138126	Standard
# #		'GL000214.1'	137718	Standard
# #		'KI270708.1'	127682	Standard
# #		'KI270730.1'	112551	Standard
# #		'KI270438.1'	112505	Standard
# #		'KI270737.1'	103838	Standard
# #		'KI270721.1'	100316	Standard
# #		'KI270738.1'	99375	Standard
# #		'KI270748.1'	93321	Standard
# #		'KI270435.1'	92983	Standard
# #		'GL000208.1'	92689	Standard
# #		'KI270538.1'	91309	Standard
# #		'KI270756.1'	79590	Standard
# #		'KI270739.1'	73985	Standard
# #		'KI270757.1'	71251	Standard
# #		'KI270709.1'	66860	Standard
# #		'KI270746.1'	66486	Standard
# #		'KI270753.1'	62944	Standard
# #		'KI270589.1'	44474	Standard
# #		'KI270726.1'	43739	Standard
# #		'KI270735.1'	42811	Standard
# #		'KI270711.1'	42210	Standard
# #		'KI270745.1'	41891	Standard
# #		'KI270714.1'	41717	Standard
# #		'KI270732.1'	41543	Standard
# #		'KI270713.1'	40745	Standard
# #		'KI270754.1'	40191	Standard
# #		'KI270710.1'	40176	Standard
# #		'KI270717.1'	40062	Standard
# #		'KI270724.1'	39555	Standard
# #		'KI270720.1'	39050	Standard
# #		'KI270723.1'	38115	Standard
# #		'KI270718.1'	38054	Standard
# #		'KI270317.1'	37690	Standard
# #		'KI270740.1'	37240	Standard
# #		'KI270755.1'	36723	Standard
# #		'KI270707.1'	32032	Standard
# #		'KI270579.1'	31033	Standard
# #		'KI270752.1'	27745	Standard
# #		'KI270512.1'	22689	Standard
# #		'KI270322.1'	21476	Standard
# #		'MT'	16569	Standard
# #		'GL000226.1'	15008	Standard
# #		'KI270311.1'	12399	Standard
# #		'KI270366.1'	8320	Standard
# #		'KI270511.1'	8127	Standard
# #		'KI270448.1'	7992	Standard
# #		'KI270521.1'	7642	Standard
# #		'KI270581.1'	7046	Standard
# #		'KI270582.1'	6504	Standard
# #		'KI270515.1'	6361	Standard
# #		'KI270588.1'	6158	Standard
# #		'KI270591.1'	5796	Standard
# #		'KI270522.1'	5674	Standard
# #		'KI270507.1'	5353	Standard
# #		'KI270590.1'	4685	Standard
# #		'KI270584.1'	4513	Standard
# #		'KI270320.1'	4416	Standard
# #		'KI270382.1'	4215	Standard
# #		'KI270468.1'	4055	Standard
# #		'KI270467.1'	3920	Standard
# #		'KI270362.1'	3530	Standard
# #		'KI270517.1'	3253	Standard
# #		'KI270593.1'	3041	Standard
# #		'KI270528.1'	2983	Standard
# #		'KI270587.1'	2969	Standard
# #		'KI270364.1'	2855	Standard
# #		'KI270371.1'	2805	Standard
# #		'KI270333.1'	2699	Standard
# #		'KI270374.1'	2656	Standard
# #		'KI270411.1'	2646	Standard
# #		'KI270414.1'	2489	Standard
# #		'KI270510.1'	2415	Standard
# #		'KI270390.1'	2387	Standard
# #		'KI270375.1'	2378	Standard
# #		'KI270420.1'	2321	Standard
# #		'KI270509.1'	2318	Standard
# #		'KI270315.1'	2276	Standard
# #		'KI270302.1'	2274	Standard
# #		'KI270518.1'	2186	Standard
# #		'KI270530.1'	2168	Standard
# #		'KI270304.1'	2165	Standard
# #		'KI270418.1'	2145	Standard
# #		'KI270424.1'	2140	Standard
# #		'KI270417.1'	2043	Standard
# #		'KI270508.1'	1951	Standard
# #		'KI270303.1'	1942	Standard
# #		'KI270381.1'	1930	Standard
# #		'KI270529.1'	1899	Standard
# #		'KI270425.1'	1884	Standard
# #		'KI270396.1'	1880	Standard
# #		'KI270363.1'	1803	Standard
# #		'KI270386.1'	1788	Standard
# #		'KI270465.1'	1774	Standard
# #		'KI270383.1'	1750	Standard
# #		'KI270384.1'	1658	Standard
# #		'KI270330.1'	1652	Standard
# #		'KI270372.1'	1650	Standard
# #		'KI270548.1'	1599	Standard
# #		'KI270580.1'	1553	Standard
# #		'KI270387.1'	1537	Standard
# #		'KI270391.1'	1484	Standard
# #		'KI270305.1'	1472	Standard
# #		'KI270373.1'	1451	Standard
# #		'KI270422.1'	1445	Standard
# #		'KI270316.1'	1444	Standard
# #		'KI270338.1'	1428	Standard
# #		'KI270340.1'	1428	Standard
# #		'KI270583.1'	1400	Standard
# #		'KI270334.1'	1368	Standard
# #		'KI270429.1'	1361	Standard
# #		'KI270393.1'	1308	Standard
# #		'KI270516.1'	1300	Standard
# #		'KI270389.1'	1298	Standard
# #		'KI270466.1'	1233	Standard
# #		'KI270388.1'	1216	Standard
# #		'KI270544.1'	1202	Standard
# #		'KI270310.1'	1201	Standard
# #		'KI270412.1'	1179	Standard
# #		'KI270395.1'	1143	Standard
# #		'KI270376.1'	1136	Standard
# #		'KI270337.1'	1121	Standard
# #		'KI270335.1'	1048	Standard
# #		'KI270378.1'	1048	Standard
# #		'KI270379.1'	1045	Standard
# #		'KI270329.1'	1040	Standard
# #		'KI270419.1'	1029	Standard
# #		'KI270336.1'	1026	Standard
# #		'KI270312.1'	998	Standard
# #		'KI270539.1'	993	Standard
# #		'KI270385.1'	990	Standard
# #		'KI270423.1'	981	Standard
# #		'KI270392.1'	971	Standard
# #		'KI270394.1'	970	Standard
# #-----------------------------------------------
#
# 00:00:32	Predicting variants
# 00:00:32	Loading sequences for chromosome '3' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.3.bin'
# 00:00:34	Building sequence tree for chromosome '3'
# 00:00:34	Done. Loaded 1592 sequences.
# 00:00:35	Loading sequences for chromosome '6' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.6.bin'
# 00:00:37	Building sequence tree for chromosome '6'
# 00:00:37	Done. Loaded 1815 sequences.
# 00:00:38	Loading sequences for chromosome '15' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.15.bin'
# 00:00:39	Building sequence tree for chromosome '15'
# 00:00:39	Done. Loaded 1001 sequences.
# 00:00:39	Loading sequences for chromosome '19' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.19.bin'
# 00:00:40	Building sequence tree for chromosome '19'
# 00:00:40	Done. Loaded 1587 sequences.
# 00:00:40	Loading sequences for chromosome '22' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.22.bin'
# 00:00:41	Building sequence tree for chromosome '22'
# 00:00:41	Done. Loaded 774 sequences.
# 00:00:41		10000 variants (1093 variants per second), 9981 VCF entries
# 00:00:41	Loading sequences for chromosome '1' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.1.bin'
# 00:00:44	Building sequence tree for chromosome '1'
# 00:00:44	Done. Loaded 3134 sequences.
# 00:00:47	Loading sequences for chromosome '2' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.2.bin'
# 00:00:49	Building sequence tree for chromosome '2'
# 00:00:49	Done. Loaded 2321 sequences.
# 00:00:50	Loading sequences for chromosome '4' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.4.bin'
# 00:00:52	Building sequence tree for chromosome '4'
# 00:00:52	Done. Loaded 1617 sequences.
# 00:00:52	Loading sequences for chromosome '5' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.5.bin'
# 00:00:54	Building sequence tree for chromosome '5'
# 00:00:54	Done. Loaded 1654 sequences.
# 00:00:54		20000 variants (904 variants per second), 19974 VCF entries
# 00:00:54	Loading sequences for chromosome '7' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.7.bin'
# 00:00:56	Building sequence tree for chromosome '7'
# 00:00:56	Done. Loaded 1692 sequences.
# 00:00:57	Loading sequences for chromosome '8' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.8.bin'
# 00:00:58	Building sequence tree for chromosome '8'
# 00:00:58	Done. Loaded 1377 sequences.
# 00:00:59	Loading sequences for chromosome '9' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.9.bin'
# 00:01:01	Building sequence tree for chromosome '9'
# 00:01:01	Done. Loaded 1414 sequences.
# 00:01:01	Loading sequences for chromosome '10' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.10.bin'
# 00:01:02	Building sequence tree for chromosome '10'
# 00:01:02	Done. Loaded 1328 sequences.
# 00:01:04	Loading sequences for chromosome '11' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.11.bin'
# 00:01:05	Building sequence tree for chromosome '11'
# 00:01:05	Done. Loaded 1874 sequences.
# 00:01:06		30000 variants (897 variants per second), 29955 VCF entries
# 00:01:06	Loading sequences for chromosome '12' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.12.bin'
# 00:01:07	Building sequence tree for chromosome '12'
# 00:01:07	Done. Loaded 1521 sequences.
# 00:01:07	Loading sequences for chromosome '13' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.13.bin'
# 00:01:08	Building sequence tree for chromosome '13'
# 00:01:08	Done. Loaded 814 sequences.
# 00:01:08	Loading sequences for chromosome '14' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.14.bin'
# 00:01:09	Building sequence tree for chromosome '14'
# 00:01:09	Done. Loaded 1181 sequences.
# 00:01:10	Loading sequences for chromosome '16' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.16.bin'
# 00:01:11	Building sequence tree for chromosome '16'
# 00:01:11	Done. Loaded 1228 sequences.
# 00:01:11	Loading sequences for chromosome '17' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.17.bin'
# 00:01:12	Building sequence tree for chromosome '17'
# 00:01:12	Done. Loaded 1468 sequences.
# 00:01:12	Loading sequences for chromosome '18' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.18.bin'
# 00:01:13	Building sequence tree for chromosome '18'
# 00:01:13	Done. Loaded 632 sequences.
# 00:01:13	Loading sequences for chromosome '20' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.20.bin'
# 00:01:14	Building sequence tree for chromosome '20'
# 00:01:14	Done. Loaded 865 sequences.
# 00:01:14		40000 variants (956 variants per second), 39942 VCF entries
# 00:01:14	Loading sequences for chromosome '21' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.21.bin'
# 00:01:14	Building sequence tree for chromosome '21'
# 00:01:14	Done. Loaded 523 sequences.
# 00:01:14	Loading sequences for chromosome 'X' from file '/home/kwat/miniconda3/share/snpeff-4.3.1t-2/./data/GRCh38.86/sequence.X.bin'
# 00:01:16	Building sequence tree for chromosome 'X'
# 00:01:16	Done. Loaded 1694 sequences.
#
# WARNINGS: Some warning were detected
# Warning type	Number of warnings
# INFO_REALIGN_3_PRIME	2231
# WARNING_TRANSCRIPT_INCOMPLETE	11874
# WARNING_TRANSCRIPT_INCOMPLETE&INFO_REALIGN_3_PRIME	158
# WARNING_TRANSCRIPT_MULTIPLE_STOP_CODONS	189
# WARNING_TRANSCRIPT_NO_START_CODON	9832
# WARNING_TRANSCRIPT_NO_START_CODON&INFO_REALIGN_3_PRIME	200
# WARNING_TRANSCRIPT_NO_STOP_CODON	6332
# WARNING_TRANSCRIPT_NO_STOP_CODON&INFO_REALIGN_3_PRIME	45
#
#
# 00:01:16	Creating summary file: /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/stats.csv
# 00:01:16	Creating summary file: /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/stats.html
# 00:01:16	Creating genes file: /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/stats.genes.txt
# 00:01:18	done.
# 00:01:18	Done.
# `tabix /home/kwat/garden/sample/process_germ_dna/find_variant/snpeff/snpeff.vcf.gz`
# (2019-06-24T21:31:07.803) Done in 7 minutes, 279 milliseconds.
